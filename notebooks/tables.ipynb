# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../h4_linear_quasi_symmetry_comm_optimization.csv")

# %%
df.columns
# Out:
# Index(['Molecule', 'Geometry_Param', 'E_FCI', 'V_0', 'V_optimized',
#        'Sum_CommSq_0', 'Sum_CommSq_Optimized', 'a_opt', 'b_opt', 'c_opt'],
#       dtype='object')

# %%
for i, row in df.iterrows():
    to_print = "{0:1.3f} & {1:1.4e} & {2:1.4e} & ".format(
        row["Geometry_Param"], row["V_0"], row["V_optimized"])

    comm_reduction = row["Sum_CommSq_0"] / row["Sum_CommSq_Optimized"]

    to_print += "{0:1.5e} & {1:1.5e} & {2:1.4f} & ".format(
        row["Sum_CommSq_0"], row["Sum_CommSq_Optimized"], comm_reduction)

    to_print += r"{0:1.1f} : {1:1.1f} : {2:1.3f} \\".format(
        row["a_opt"], row["b_opt"], row["c_opt"])
    print(to_print)
# Out:
# 0.600 & 1.8922e-03 & 1.9059e-03 & 1.74882e-02 & 1.74234e-02 & 1.0037 & 1.0 : 1.0 : -1.994 \\
# 1.089 & 9.9071e-03 & 9.9498e-03 & 1.06866e-02 & 1.06361e-02 & 1.0047 & 1.0 : 1.0 : -1.913 \\
# 1.578 & 2.7826e-02 & 2.7840e-02 & 7.03335e-03 & 7.02717e-03 & 1.0009 & 1.0 : 1.0 : -1.959 \\
# 2.067 & 5.1900e-02 & 5.1951e-02 & 9.61836e-03 & 9.61490e-03 & 1.0004 & 1.0 : 1.0 : -1.959 \\
# 2.556 & 4.1484e-02 & 4.1781e-02 & 4.52009e-04 & 3.52027e-04 & 1.2840 & 1.0 : 1.0 : -1.998 \\
# 3.044 & 5.1066e-02 & 5.1306e-02 & 5.02167e-03 & 4.97295e-03 & 1.0098 & 1.0 : 1.0 : -1.985 \\
# 3.533 & 2.0741e-02 & 2.0897e-02 & 8.93768e-05 & 2.79758e-05 & 3.1948 & 1.0 : 1.0 : -2.000 \\
# 4.022 & 4.1355e-02 & 4.1667e-02 & 1.30943e-04 & 8.37292e-07 & 156.3892 & 1.0 : 1.0 : -2.000 \\
# 4.511 & 2.1683e-02 & 2.1755e-02 & 6.11364e-04 & 6.11037e-04 & 1.0005 & 1.0 : 1.0 : -1.966 \\
# 5.000 & 2.3451e-02 & 2.3175e-02 & 1.59532e-03 & 1.59056e-03 & 1.0030 & 1.0 : 1.0 : -1.919 \\
