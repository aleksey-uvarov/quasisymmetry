# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../h2o_quasi_symmetry_v_to_comm.csv")

# %%
df.columns
# Out:
# Index(['Molecule', 'Geometry_Param', 'E_FCI', 'V_0', 'V_optimized',
#        'Sum_CommSq_0', 'Sum_CommSq_Optimized', 'a_opt', 'b_opt', 'c_opt'],
#       dtype='object')

# %%
for i, row in df.iterrows():
    to_print = "{0:1.3f} & {1:1.4e} & {2:1.4e} & ".format(
        row["Geometry_Param"], row["V_0"], row["V_optimized"])

    comm_reduction = row["Sum_CommSq_0"] / row["Sum_CommSq_Optimized"]

    to_print += "{0:1.5e} & {1:1.5e} & {2:1.4f} & ".format(
        row["Sum_CommSq_0"], row["Sum_CommSq_Optimized"], comm_reduction)

    to_print += r"{0:1.1f} : {1:1.1f} : {2:1.3f} \\".format(
        row["a_opt"], row["b_opt"], row["c_opt"])
    print(to_print)
# Out:
# 0.958 & 1.9114e-03 & 1.9116e-03 & 9.61936e-03 & 9.61865e-03 & 1.0001 & 1.0 : 1.0 : -1.961 \\
# 1.129 & 2.8398e-03 & 2.8419e-03 & 8.84311e-03 & 8.83894e-03 & 1.0005 & 1.0 : 1.0 : -1.963 \\
# 1.301 & 4.0687e-03 & 4.0715e-03 & 7.42560e-03 & 7.42208e-03 & 1.0005 & 1.0 : 1.0 : -1.971 \\
# 1.472 & 6.5119e-03 & 6.5122e-03 & 5.64258e-03 & 5.64235e-03 & 1.0000 & 1.0 : 1.0 : -1.978 \\
# 1.643 & 1.3113e-02 & 1.3126e-02 & 3.81575e-03 & 3.80775e-03 & 1.0021 & 1.0 : 1.0 : -1.986 \\
# 1.815 & 4.1440e-02 & 4.1568e-02 & 1.24898e-02 & 1.24288e-02 & 1.0049 & 1.0 : 1.0 : -1.929 \\
# 1.986 & 1.6301e-02 & 1.7934e-02 & 4.37230e+00 & 4.21556e+00 & 1.0372 & 1.0 : 1.0 : -0.971 \\
# 2.157 & 8.0139e-02 & 8.1483e-02 & 1.86011e-03 & 1.29097e-03 & 1.4409 & 1.0 : 1.0 : -1.996 \\
# 2.329 & 9.8915e-02 & 1.0104e-01 & 2.08809e-03 & 1.17847e-03 & 1.7719 & 1.0 : 1.0 : -1.996 \\
# 2.500 & 5.8600e-02 & 5.8519e-02 & 2.46929e-02 & 2.46669e-02 & 1.0011 & 1.0 : 1.0 : -1.457 \\
