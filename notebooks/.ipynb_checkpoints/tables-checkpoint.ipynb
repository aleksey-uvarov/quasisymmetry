# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../lih_quasi_symmetry_comm_optimization.csv")

# %%
df.columns
# Out:
# Index(['Molecule', 'Geometry_Param', 'E_FCI', 'V_0', 'V_optimized',
#        'Sum_CommSq_0', 'Sum_CommSq_Optimized', 'a_opt', 'b_opt', 'c_opt'],
#       dtype='object')

# %%
for i, row in df.iterrows():
    to_print = "{0:1.3f} & {1:1.4f} & {2:1.4f} & ".format(
        row["Geometry_Param"], row["V_0"], row["V_optimized"])

    comm_reduction = row["Sum_CommSq_0"] / row["Sum_CommSq_Optimized"]

    to_print += "{0:1.5e} & {1:1.5e} & {2:1.4f} & ".format(
        row["Sum_CommSq_0"], row["Sum_CommSq_Optimized"], comm_reduction)

    to_print += r"{0:1.1f} : {1:1.1f} : {2:1.3f} \\".format(
        row["a_opt"], row["b_opt"], row["c_opt"])
    print(to_print)
# Out:
# 0.800 & 0.0020 & 0.0730 & 1.81878e-03 & 1.81827e-03 & 1.0003 & 1.0 : 1.0 : -1.991 \\
# 1.378 & 0.0024 & 0.1059 & 1.22159e-03 & 1.21675e-03 & 1.0040 & 1.0 : 1.0 : -2.029 \\
# 1.956 & 0.0070 & 0.0705 & 2.19385e-03 & 2.18273e-03 & 1.0051 & 1.0 : 1.0 : -2.042 \\
# 2.533 & 0.0262 & 0.1740 & 5.89615e-03 & 5.88328e-03 & 1.0022 & 1.0 : 1.0 : -2.042 \\
# 3.111 & 0.0504 & 0.1439 & 1.27495e-02 & 1.27442e-02 & 1.0004 & 1.0 : 1.0 : -1.976 \\
# 3.689 & 0.0423 & 0.1814 & 1.21622e-02 & 1.21425e-02 & 1.0016 & 1.0 : 1.0 : -1.959 \\
# 4.267 & 0.0218 & 0.1464 & 6.19207e-03 & 6.18716e-03 & 1.0008 & 1.0 : 1.0 : -1.981 \\
# 4.844 & 0.0037 & 0.4986 & 9.09121e-04 & 7.15032e-04 & 1.2714 & 1.0 : -1.0 : -0.000 \\
# 5.422 & 0.0059 & 0.1563 & 1.69335e-03 & 1.69022e-03 & 1.0019 & 1.0 : 1.0 : -1.986 \\
# 6.000 & 0.0010 & 0.1477 & 2.42028e-04 & 2.37585e-04 & 1.0187 & 1.0 : 1.0 : -1.872 \\
